# %%
import City_Preprocessing as bkPro
import pandas as pd

# %%
city_raw = pd.read_csv('/Users/briankalinowski/PycharmProjects/CIS600/zecon/City_time_series.csv')

# Should ALWAYS have Date and RegionName
features = ['Date', 'RegionName',
                'PriceToRentRatio_AllHomes',
                'ZRI_AllHomes',
                'ZriPerSqft_AllHomes',
                'Zri_SingleFamilyResidenceRental']

# all our measurement Featreus
values = ['PriceToRentRatio_AllHomes',
                'ZRI_AllHomes',
                'ZriPerSqft_AllHomes',
                'Zri_SingleFamilyResidenceRental']

lookup_ix = ['State', 'City']
full_ix = ['State', 'City', 'Date']



city_test = bkPro.process_city_data(city_raw, features, values, lookup_ix, full_ix)
# Out:
# /anaconda/envs/CIS600/lib/python3.7/site-packages/pandas/core/frame.py:4034: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   downcast=downcast, **kwargs)
# DROPPED: ST: VA CITY: Broadway NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: MO CITY: Mountain Grove NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: WI CITY: Edgerton NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: OH CITY: Kelleys Island NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: MN CITY: Adrian NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: WI CITY: Rockland NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: IA CITY: Lake Park NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: NC CITY: Creston NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: AL CITY: Crane Hill NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: CA CITY: La Grange NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: NY CITY: Lenox NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: MI CITY: Pinconning NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: MD CITY: Chestertown NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: VA CITY: Capron NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: PA CITY: Ellport NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: WV CITY: West Milford NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: KY CITY: Benton NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: MI CITY: Sidney NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: IA CITY: Dallas NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: IL CITY: Davis NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: NC CITY: Gamewell NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: PA CITY: Eaton Township NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: GA CITY: Townsend NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: NC CITY: Clarkton NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: TX CITY: San Leon NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: TX CITY: Flower Mound NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: WA CITY: Asotin NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: NY CITY: East Northport NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: IL CITY: Mount Vernon NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: WV CITY: Kenova NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: LA CITY: Morgan City NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: MS CITY: Raleigh NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: CO CITY: Howard NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: LA CITY: Bunkie NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: WV CITY: Shenandoah Junction NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: WV CITY: Belle NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: NJ CITY: Sea Girt NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: NY CITY: Lindenhurst NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: IN CITY: West Terre Haute NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: MS CITY: Meridian NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: NY CITY: Port Dickinson NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: PA CITY: Uniontown NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: NC CITY: North Wilkesboro NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: VA CITY: Atkins NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: TX CITY: Nash NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: IN CITY: Haubstadt NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: VA CITY: Free Union NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: PA CITY: Dreher Township NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: VA CITY: Reedville NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: WI CITY: Suamico NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: IL CITY: Herscher NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: MO CITY: Velda Village NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: MI CITY: Frankfort NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: PA CITY: Lackawannock Township NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: IL CITY: Illiopolis NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: WI CITY: Town of Darien NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: MI CITY: Croswell NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: ME CITY: Wells NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: MI CITY: Sebewaing NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: IL CITY: Momence NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: DE CITY: Millsboro NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: CA CITY: Wofford Heights NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: IN CITY: Logansport NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: MN CITY: Crosby NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: KY CITY: Woodburn NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: AL CITY: Oneonta NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: IN CITY: Francisco NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: LA CITY: Walker NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: IL CITY: Bellevue NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: MI CITY: Luther NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: VA CITY: Wise NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: GA CITY: Pelham NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: SD CITY: Volga NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: IL CITY: Monmouth NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: IN CITY: Camden NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: OH CITY: Cherry Grove NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: WI CITY: Grand Chute NaN Columns: ['ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: NY CITY: Town of Holland NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: IL CITY: West Frankfort NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: MS CITY: Dundee NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: ME CITY: Auburn NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: NE CITY: Hastings NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: VT CITY: Royalton NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: GA CITY: Cordele NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: IA CITY: Madrid NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: KY CITY: Jeffersonville NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: HI CITY: Haiku NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: TN CITY: Calhoun NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: FL CITY: Norland NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: OH CITY: Clarington NaN Columns: ['PriceToRentRatio_AllHomes']
# DROPPED: ST: PA CITY: Rayburn Township NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: MI CITY: Auburn NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: MN CITY: Angora NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: VA CITY: Meadowview NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: IA CITY: Long Grove NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: OH CITY: Madeira NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: ID CITY: Ketchum NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: GA CITY: Trion NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: MI CITY: Covert NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: CA CITY: Point Reyes Station NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: IL CITY: Bunker Hill NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: ME CITY: Clifton NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: TX CITY: Red Oak NaN Columns: ['ZRI_AllHomes']
#
# DROPPED: ST: MA CITY: Marion NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: NY CITY: Eaton NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: MS CITY: Toomsuba NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: TX CITY: Seminole NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: GA CITY: Clermont NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: MA CITY: Huntington NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: MN CITY: Arlington NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: TN CITY: Big Sandy NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: IL CITY: Durand NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: LA CITY: Maurepas NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: IL CITY: Mount Olive NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: AZ CITY: Saint Johns NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: ME CITY: Turner NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: OK CITY: Prague NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: PA CITY: Ebensburg NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: MI CITY: Elmira NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: TX CITY: Woodcreek NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: WI CITY: Pittsfield NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: VT CITY: Wolcott NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: IL CITY: Shawneetown NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: VA CITY: Shipman NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: PA CITY: Wayne Heights NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: TX CITY: Thorndale NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: OH CITY: Leipsic NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: TX CITY: Elkhart NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: OK CITY: Oilton NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: OH CITY: Woodsfield NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: VA CITY: Appomattox NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: MO CITY: Taneyville NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: NY CITY: Town of Shelter Island NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: IL CITY: Peru NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: VT CITY: Bridport NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: VT CITY: Town of Bristol NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: PA CITY: Kane NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: NY CITY: Vienna NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: NM CITY: Eunice NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: IL CITY: Coulterville NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: FL CITY: Eastpoint NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: VT CITY: Starksboro NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: TN CITY: Henderson NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: OH CITY: Sardinia NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: OH CITY: Spring Valley NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: TN CITY: Bethel Springs NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: ME CITY: Liberty NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: WA CITY: Riverside NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: AK CITY: Knik-Fairview NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: NY CITY: Arcade NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: OK CITY: Kellyville NaN Columns: ['ZRI_AllHomes']
#
# DROPPED: ST: TN CITY: Mooresburg NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: VT CITY: Shoreham NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: WI CITY: Brothertown NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: WI CITY: Whitelaw NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: LA CITY: White Castle NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: PA CITY: Lenape Heights NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: IL CITY: Stonington NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: KS CITY: Hugoton NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: WI CITY: Necedah NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: NH CITY: Moultonborough NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: WI CITY: Knapp NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: WI CITY: Porterfield NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: GA CITY: Brooks NaN Columns: ['Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: TX CITY: Cuero NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: WI CITY: Oneida NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: LA CITY: Homer NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: VA CITY: Pulaski NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: WA CITY: Ridgefield NaN Columns: ['ZRI_AllHomes']
#
# DROPPED: ST: WA CITY: Clarkston NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: MI CITY: Hemlock NaN Columns: ['ZRI_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: LA CITY: Minden NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: KY CITY: Hanson NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
# DROPPED: ST: KS CITY: Caldwell NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: WI CITY: Whiting NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: ME CITY: Minot NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: CA CITY: Pearblossom NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: LA CITY: Independence NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: MN CITY: Pelican Rapids NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: MI CITY: Potterville NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: TX CITY: Vidor NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: FL CITY: Fort Myers Beach NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: CO CITY: Mountain Village NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: WI CITY: Osceola NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: WV CITY: Bethlehem NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: PA CITY: Lawson Heights NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: NC CITY: Rutherfordton NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: TN CITY: Maynardville NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: NY CITY: Westhampton NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: SC CITY: Waterloo NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: KY CITY: Calvert City NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: TX CITY: Bishop NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: MN CITY: Le Roy NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: MN CITY: Darwin NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: MO CITY: Bonne Terre NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: PA CITY: Bradford Township NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: TX CITY: Highland Park NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: ME CITY: Poland NaN Columns: ['ZRI_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: MS CITY: Jackson NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: IL CITY: East Peoria NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: MI CITY: Akron NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: TX CITY: El Lago NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: IL CITY: Fulton NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: TX CITY: China Spring NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: MI CITY: Alger NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: TX CITY: Little Elm NaN Columns: ['PriceToRentRatio_AllHomes', 'ZRI_AllHomes']
#
# DROPPED: ST: IN CITY: Owensville NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: IL CITY: Hanover NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: WI CITY: Crivitz NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: NV CITY: Lovelock NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: LA CITY: Chalmette NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: NC CITY: Hays NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: VT CITY: St Johnsbury NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: VT CITY: Londonderry NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: MI CITY: Elwell NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: IL CITY: Franklin Grove NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: NM CITY: Las Vegas NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: NY CITY: Utica NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: TN CITY: Darden NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: IL CITY: Port Byron NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: WV CITY: Eskdale NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: NY CITY: Manorville NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: MN CITY: Fort Ripley NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: IA CITY: Saint Charles NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: IN CITY: Memphis NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: NC CITY: Catawba NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: TX CITY: Port Lavaca NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: GA CITY: Manchester NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: WI CITY: Poygan NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: MO CITY: Willow Springs NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: WI CITY: Muscoda NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: PA CITY: Dennison Township NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: PA CITY: Treasure Lake NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: TX CITY: Hamshire NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: NC CITY: Lake Junaluska NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: PA CITY: Sayre NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: WI CITY: Town of Port Washington NaN Columns: ['ZRI_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: OH CITY: Mack North NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: IL CITY: Illinois City NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: WI CITY: Norway NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: MN CITY: Laporte NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: VA CITY: Weber City NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: IN CITY: Poland NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: MI CITY: Spring Arbor NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: NY CITY: Miller Place NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: FL CITY: Surfside NaN Columns: ['ZRI_AllHomes']
#
# DROPPED: ST: IN CITY: La Fontaine NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: VT CITY: Mt Holly NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: NY CITY: Jewett NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: MI CITY: Big Rapids Township NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: IL CITY: Gillespie NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: TX CITY: Spur NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: NY CITY: Calverton NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: NY CITY: Chittenango NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: NC CITY: Warrensville NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: NC CITY: Hertford NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: GA CITY: Edison NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: CA CITY: Tuolumne NaN Columns: ['PriceToRentRatio_AllHomes']
# DROPPED: ST: WI CITY: Black Wolf NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: NC CITY: Rocky Mount NaN Columns: ['ZRI_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: TX CITY: Somerset NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: NM CITY: Hobbs NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: LA CITY: Raceland NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: TX CITY: La Marque NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: PA CITY: Huston Township NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: WI CITY: Cadott NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: MN CITY: Blue Earth NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: SC CITY: Pelion NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: MI CITY: Morley NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: OH CITY: Urbana NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: MI CITY: Richland NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: IA CITY: Lake Mills NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: TN CITY: Pleasant Shade NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: TX CITY: Wake Village NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: GA CITY: Eastman NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: NC CITY: Princeville NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: SC CITY: North Hartsville NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: WV CITY: Cedar Grove NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: MA CITY: Lincoln NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: WI CITY: Nekimi NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: MN CITY: Nashwauk NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: WI CITY: Suring NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: TX CITY: Orange NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: NY CITY: Town of Friendship NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: NC CITY: South Mills NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: TX CITY: Huntsville NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: NC CITY: Cooleemee NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: NY CITY: Ashland NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: IL CITY: Washington NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: MS CITY: Shubuta NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: WI CITY: Milltown NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: AK CITY: Ketchikan NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: MN CITY: McGrath NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: AZ CITY: Forest Lakes NaN Columns: ['ZRI_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: MI CITY: Coral NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: NY CITY: Blue Point NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: ND CITY: Mandan NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: PA CITY: Old Forge NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: TX CITY: Payne Springs NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: ID CITY: Saint Maries NaN Columns: ['Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: TX CITY: Troup NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: PA CITY: South Connellsville NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: IA CITY: Orange City NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: MS CITY: Benton NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: MI CITY: Portsmouth Township NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: AZ CITY: Salome NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: CA CITY: Clio NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: TX CITY: Marshall NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: MI CITY: Deckerville NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: IL CITY: Riverton NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: CA CITY: Smartsville NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: WI CITY: Troy NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: IN CITY: Fillmore NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: MI CITY: Rudyard NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: OH CITY: New Concord NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: MN CITY: Grasston NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: IA CITY: Kanawha NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: KS CITY: Arkansas City NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: MI CITY: Mears NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: PA CITY: Osceola Mills NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: TX CITY: Forney NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: MI CITY: Buchanan NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: FL CITY: Key West NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: ME CITY: Southwest Harbor NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: TX CITY: Mont Belvieu NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: CA CITY: Inverness NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: CA CITY: Planada NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: PA CITY: Clearfield NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: OH CITY: Wayne NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: MS CITY: Corinth NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: ID CITY: Paul NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: NJ CITY: North Cape May NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: NY CITY: Bronxville NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: TX CITY: Boyd NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: OR CITY: Cannon Beach NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: MA CITY: Otis NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: SD CITY: Brookings NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: WI CITY: Fall River NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: SC CITY: Trenton NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: PA CITY: German Township NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: GA CITY: Greenville NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: NC CITY: Columbus NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: IL CITY: Winnebago NaN Columns: ['ZriPerSqft_AllHomes']
# DROPPED: ST: NE CITY: Mitchell NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: MO CITY: Farmington NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: VA CITY: Collinsville NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: AL CITY: Grady NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: SC CITY: Chappells NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: TX CITY: Alvin NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: WV CITY: Winfield NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: TX CITY: New Waverly NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: TX CITY: Anson NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: WA CITY: Colfax NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: NY CITY: Town of Mexico NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: ID CITY: Deary NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: MI CITY: Johannesburg NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: MN CITY: Preston NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: GA CITY: Darien NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: TX CITY: Wortham NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: NC CITY: Otto NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: CO CITY: Nathrop NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: ID CITY: Preston NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: TX CITY: Friendswood NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: UT CITY: Cottonwood Heights NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: MI CITY: Morrice NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: NY CITY: Town of Remsen NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: MI CITY: Ossineke NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: VT CITY: Town of Poultney NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: IL CITY: Gilman NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: LA CITY: Kaplan NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: KS CITY: Hesston NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: NY CITY: Willsboro NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: VA CITY: Narrows NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: NJ CITY: Rio Grande NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: IA CITY: Manning NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: FL CITY: Marathon NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: GA CITY: Thomasville NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: TX CITY: Edna NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: LA CITY: Lake Arthur NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: MI CITY: Charlevoix NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: AL CITY: Joppa NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: WI CITY: Geneva NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: FL CITY: Loughman NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: IL CITY: Big Rock NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: KY CITY: Mount Sterling NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: MS CITY: Richland NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: IL CITY: Shannon NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: MS CITY: Bogue Chitto NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: NY CITY: Kiantone NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: MN CITY: Cross Lake NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: WI CITY: Lawrence NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: IL CITY: Onarga NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: NY CITY: Atlantic Beach NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: MI CITY: Gaines NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: NY CITY: Paris NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: UT CITY: Delta NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: LA CITY: Eros NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: NC CITY: White Oak NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: CO CITY: Hesperus NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: IA CITY: Kellogg NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: IL CITY: Ladd NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: CA CITY: Le Grand NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: WI CITY: Highland NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: MI CITY: Corunna NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: WI CITY: Albany NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: MI CITY: Port Hope NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: MN CITY: Breezy Point NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: MD CITY: Bozman NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: IA CITY: Ogden NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: NY CITY: Jamestown NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: IN CITY: Ferdinand NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: IA CITY: Lake View NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: MI CITY: Caseville NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: MS CITY: Philadelphia NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: VT CITY: Bethel NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: GA CITY: Hephzibah NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: NY CITY: Hague NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: WI CITY: Random Lake NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: TN CITY: Plainview NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: TX CITY: Nixon NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: NC CITY: Forest City NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: WV CITY: Stonewood NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: IL CITY: Rushville NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: MT CITY: Bozeman NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: WV CITY: Huntington NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: IN CITY: Loogootee NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: NY CITY: Mendon NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: NC CITY: Stanfield NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
# DROPPED: ST: OH CITY: West Portsmouth NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: WA CITY: Amboy NaN Columns: ['ZRI_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: TX CITY: Waco NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: NY CITY: Sheldon NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: WI CITY: Osseo NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: IL CITY: Sherrard NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: NV CITY: Genoa NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: MI CITY: Scotts NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: NY CITY: Town of Otego NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: PA CITY: Springhill NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: IN CITY: Celestine NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: WI CITY: Sobieski NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: WI CITY: Glendale NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: GA CITY: Reidsville NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: OK CITY: Stroud NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: WI CITY: Newburg NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: MI CITY: Allegan NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: TX CITY: Hide A Way NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: MS CITY: Burnsville NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: WV CITY: Keyser NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: PA CITY: Geistown NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: IL CITY: Toluca NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: IL CITY: Bluford NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: OH CITY: North Canton NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: TX CITY: Ranchitos Las Lomas NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: TN CITY: Michie NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: MI CITY: Mattawan NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: TN CITY: Parrottsville NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: MS CITY: Madison NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: VT CITY: Chittenden NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: WI CITY: Shawano NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: NC CITY: Purlear NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: TX CITY: Llano NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: CA CITY: Pinecrest NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: WA CITY: Goldendale NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: OH CITY: Hartville NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: NY CITY: Falconer NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: MO CITY: Lebanon NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: NY CITY: Lisbon NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: NH CITY: Lyme NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: PA CITY: Oil Creek NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: VA CITY: Bluemont NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: MI CITY: Barryton NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: MI CITY: East Leroy NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: AL CITY: Danville NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: NJ CITY: Ventnor City NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: IA CITY: Lacona NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: MI CITY: Pleasant Lake NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: TX CITY: Gilmer NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: WA CITY: Ashford NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: NV CITY: Glenbrook NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: FL CITY: Sneads NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: AR CITY: Mineral Springs NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: GA CITY: Sea Island NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: NJ CITY: Stone Harbor NaN Columns: ['ZRI_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: GA CITY: Hawkinsville NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: NC CITY: Burgaw NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: NY CITY: Verona NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# ...
#
# DROPPED: ST: PA CITY: Westmont NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: IL CITY: Hillsdale NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: HI CITY: Waimea NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: VT CITY: Rockingham NaN Columns: ['ZriPerSqft_AllHomes']
# DROPPED: ST: WI CITY: Cornell NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: LA CITY: Westlake NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: NY CITY: Edmeston NaN Columns: ['ZRI_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: IN CITY: Dubois NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: GA CITY: Lenox NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: ME CITY: Woolwich NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: NY CITY: Hector NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: WV CITY: Benwood NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: TX CITY: Whitehouse NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: MN CITY: Wykoff NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: PA CITY: West Mahanoy Township NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: IL CITY: Marseilles NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: KY CITY: Prospect NaN Columns: ['ZRI_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: IN CITY: Chrisney NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: VA CITY: Union Hall NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: CA CITY: Santa Barbara NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: PA CITY: Hegins NaN Columns: ['ZRI_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: WI CITY: Frederic NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: VA CITY: Luray NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: LA CITY: Iota NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: OH CITY: Pemberville NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: IN CITY: West Baden Springs NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: AL CITY: Abbeville NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: KY CITY: Elkton NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: IL CITY: Hinckley NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: MA CITY: Monterey NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: GA CITY: East Dublin NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: PA CITY: Lower Yoder Township NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: MI CITY: Milan NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: SC CITY: Sharon NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: MS CITY: Byhalia NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: PA CITY: Jefferson Township NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: PA CITY: Glen Lyon NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: TX CITY: Boling NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: TX CITY: Timpson NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: WI CITY: Melrose NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: GA CITY: Summerville NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: IL CITY: Williamsville NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: PA CITY: Waynesburg NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: MS CITY: Prentiss NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: MI CITY: Union NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: ID CITY: Weippe NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: OH CITY: Nova NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: NY CITY: Indian Lake NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: GA CITY: Camilla NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: NY CITY: Town of Deruyter NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: LA CITY: Bastrop NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: MN CITY: Dilworth NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: WI CITY: Birnamwood NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: OR CITY: Port Orford NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: AR CITY: Plainview NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: WI CITY: Clear Lake NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: ME CITY: Smithfield NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: SC CITY: Manning NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: LA CITY: Holden NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: IL CITY: Groveland NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: WI CITY: Cuba City NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: VA CITY: Meadows of Dan NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: OH CITY: Harrod NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: IL CITY: Wenona NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: PA CITY: Kittanning Township NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: OH CITY: Shadyside NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: IA CITY: Lawton NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: TX CITY: Lake Jackson NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: IL CITY: Malta NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: MI CITY: Mulliken NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: VA CITY: Amelia Court House NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: VA CITY: Penhook NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: PA CITY: Monroe Township NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: SD CITY: Pierre NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: WI CITY: Genesee NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: GA CITY: East Griffin NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: MI CITY: Fife Lake NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: AL CITY: Grant NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: LA CITY: Plaucheville NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: PA CITY: Coudersport NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: OH CITY: Rayland NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: LA CITY: Abbeville NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: IA CITY: Forest City NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: LA CITY: Violet NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: NJ CITY: Harvey Cedars NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: WI CITY: Eagle Lake NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: NY CITY: Scriba NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: ME CITY: Town of Wilton NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: TN CITY: Hilham NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: CO CITY: Rangely NaN Columns: ['PriceToRentRatio_AllHomes']
# DROPPED: ST: VA CITY: Disputanta NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: MD CITY: Bishopville NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: MA CITY: West Stockbridge NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: WI CITY: Cleveland NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: MS CITY: Pearlington NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: TX CITY: Stafford NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: PA CITY: Pulaski NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: TX CITY: Raymondville NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: MI CITY: Burr Oak NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: UT CITY: Midway NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: TX CITY: La Villa NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: WA CITY: Pullman NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: TX CITY: Bartlett NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: NY CITY: Town of Caledonia NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: OH CITY: Bridgeport NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: TX CITY: West Lake Hills NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: MS CITY: Hazlehurst NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: OH CITY: Greenfield NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: MI CITY: Lachine NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: WI CITY: Weyauwega NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: NY CITY: Milo Mills NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: PA CITY: Shanor-Northvue NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: MS CITY: Richton NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: WI CITY: Christiana NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: IN CITY: Oolitic NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: VT CITY: Brookfield NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: TX CITY: Lost Creek NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: MI CITY: Beecher NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: IL CITY: Thomasboro NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: AR CITY: Harrison NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: WV CITY: Fairview NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: MN CITY: Pine City NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: MO CITY: Sullivan NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: NM CITY: Bayard NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: OH CITY: Tiltonsville NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: MI CITY: Allenton NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: WI CITY: Wolf River NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: OH CITY: Berlin Center NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: MI CITY: Houghton NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: WI CITY: Belleville NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: CA CITY: Soulsbyville NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: PA CITY: Barr Township NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: NM CITY: Jal NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: NJ CITY: Winfield Township NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: NH CITY: Town of Wolfeboro NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: WI CITY: Hazel Green NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: CA CITY: Los Molinos NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: MT CITY: Roundup NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: OK CITY: Henryetta NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: VT CITY: Town of Wallingford NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: WV CITY: Follansbee NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: MI CITY: Wolverine NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: MI CITY: Brimley NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: TX CITY: Waskom NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: OH CITY: Defiance NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: IL CITY: Springfield NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: IL CITY: Loda NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: VT CITY: Town of Rutland NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: AZ CITY: Happy Jack NaN Columns: ['ZRI_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: VA CITY: Berryville NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: PA CITY: Plumcreek Township NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: AL CITY: Laceys Spring NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: WI CITY: Orfordville NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: WI CITY: Medina NaN Columns: ['ZriPerSqft_AllHomes']
#
# DROPPED: ST: LA CITY: Heflin NaN Columns: ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ST: TN CITY: Rutledge NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: TN CITY: South Pittsburg NaN Columns: ['PriceToRentRatio_AllHomes', 'ZRI_AllHomes']
#
# DROPPED: ST: AR CITY: Nashville NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: TX CITY: Winnie NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: NJ CITY: Ocean City NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: AL CITY: Headland NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: TX CITY: Savoy NaN Columns: ['PriceToRentRatio_AllHomes']
#
# DROPPED: ST: MI CITY: Cass City NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: NY CITY: Town of Windham NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ST: IN CITY: Mentone NaN Columns: ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']

# %%
city_test.head()
# Out:
#   State       City  Date  AVG_PriceToRentRatio_AllHomes  AVG_ZRI_AllHomes  \
# 0    WA  Lilliwaup  2010                      12.846667       1157.000000
# 1    WA  Lilliwaup  2011                      13.190000       1105.416667
# 2    WA  Lilliwaup  2012                      14.352500        954.083333
# 3    WA  Lilliwaup  2013                      14.486667        953.000000
# 4    WA  Lilliwaup  2014                      15.205833        965.833333
#
#    AVG_ZriPerSqft_AllHomes  AVG_Zri_SingleFamilyResidenceRental
# 0                 1.069333                          1168.333333
# 1                 1.013000                          1107.750000
# 2                 0.877333                           954.166667
# 3                 0.892833                           953.333333
# 4                 0.920167                           969.166667

# %%
city_test.groupby(['State', 'City']).ngroups
# Out:
# 10131

# %% [markdown]
# # Clustering stuffs

# %%
from sklearn import metrics
from sklearn.cluster import KMeans

# %%
Kmeans_cluster = KMeans(n_clusters=2)

# %%
city_features = city_test.drop(columns=full_ix)
city_features.head()
# Out:
#    AVG_PriceToRentRatio_AllHomes  AVG_ZRI_AllHomes  AVG_ZriPerSqft_AllHomes  \
# 0                      12.846667       1157.000000                 1.069333
# 1                      13.190000       1105.416667                 1.013000
# 2                      14.352500        954.083333                 0.877333
# 3                      14.486667        953.000000                 0.892833
# 4                      15.205833        965.833333                 0.920167
#
#    AVG_Zri_SingleFamilyResidenceRental
# 0                          1168.333333
# 1                          1107.750000
# 2                           954.166667
# 3                           953.333333
# 4                           969.166667

# %%
cluster_test = Kmeans_cluster.fit_transform(city_features)

# %%
pd.DataFrame(cluster_test).head(20)
# Out:
#              0            1
# 0   263.727016  4002.238920
# 1   343.168333  4081.754923
# 2   558.750692  4297.230001
# 3   560.102747  4298.576518
# 4   539.800574  4278.234411
# 5   485.389617  4223.885993
# 6   476.622942  4215.187817
# 7   212.812170  3951.321666
# 8    13.459486  3730.088596
# 9    13.452970  3730.088779
# 10  105.309172  3843.868995
# 11  241.119216  3979.523808
# 12  206.932713  3945.562732
# 13  163.694151  3902.321561
# 14   83.852505  3822.295262
# 15   23.739751  3761.557583
# 16  522.400008  4260.924598
# 17  550.976142  4289.529273
# 18  577.488943  4316.030982
# 19  538.453224  4276.991955
