# %%
import pandas as pd

# %%
zillow_zip_raw = pd.read_csv('/Users/briankalinowski/PycharmProjects/CIS600/zecon/Zip_time_series.csv')

# Should ALWAYS have Date and RegionName
features = ['Date', 'RegionName',
                'PriceToRentRatio_AllHomes',
                'ZRI_AllHomes',
                'ZriPerSqft_AllHomes',
                'Zri_SingleFamilyResidenceRental']

# all our measurement Featreus
values = ['PriceToRentRatio_AllHomes',
                'ZRI_AllHomes',
                'ZriPerSqft_AllHomes',
                'Zri_SingleFamilyResidenceRental']

lookup_ix = ['State', 'City']
full_ix = ['State', 'City', 'Date']

# %%
def clean_zip_data(data: pd.DataFrame, features: list, search_values: list) -> pd.DataFrame:
    """
    :return: Filters zip data with features columns, Cleans NaN values from search_values
    """
    data = data.filter(features)
    data.dropna(how='all', subset=search_values, inplace=True)

    # convert date column to pd Datetime
    if 'Date' in list(data.columns):
        data.Date = pd.to_datetime(data.Date)
    return data

# %%
zillow_zip_data = clean_zip_data(zillow_zip_raw, features, values)
zillow_zip_data.head()
# Out:
#               Date  RegionName  PriceToRentRatio_AllHomes  ZRI_AllHomes  \
# 2741064 2010-10-31        1001                      11.48           NaN
# 2741065 2010-10-31        1002                      13.98           NaN
# 2741066 2010-10-31        1005                      11.09           NaN
# 2741067 2010-10-31        1007                      12.95           NaN
# 2741068 2010-10-31        1008                      12.77           NaN
#
#          ZriPerSqft_AllHomes  Zri_SingleFamilyResidenceRental
# 2741064                  NaN                              NaN
# 2741065                  NaN                              NaN
# 2741066                  NaN                              NaN
# 2741067                  NaN                              NaN
# 2741068                  NaN                              NaN

# %%
def merge_location_data(data: pd.DataFrame) -> pd.DataFrame:
    """
    :return: Merge proper city/state names to zip data
    """
    # ADD YOUR LOCAL PATH FOR cities_crosswalk.csv
    zipcode_map = pd.read_csv('/Users/briankalinowski/Desktop/CIS600_DataMining/Zillow_Data_Clean/Zillow_zipcode_map.csv')
    data.rename(columns={'RegionName': 'ZIP'}, inplace=True)
    data = data.merge(zipcode_map, on='ZIP', how='left')
    return data

# %%
zillow_zip_data = merge_location_data(zillow_zip_data)
zillow_zip_data.head()
# Out:
#         Date   ZIP  PriceToRentRatio_AllHomes  ZRI_AllHomes  \
# 0 2010-10-31  1001                      11.48           NaN
# 1 2010-10-31  1002                      13.98           NaN
# 2 2010-10-31  1005                      11.09           NaN
# 3 2010-10-31  1007                      12.95           NaN
# 4 2010-10-31  1008                      12.77           NaN
#
#    ZriPerSqft_AllHomes  Zri_SingleFamilyResidenceRental State         City
# 0                  NaN                              NaN    MA       Agawam
# 1                  NaN                              NaN    MA      Amherst
# 2                  NaN                              NaN    MA        Barre
# 3                  NaN                              NaN    MA  Belchertown
# 4                  NaN                              NaN    MA    Blandford

# %%
def get_city_state_zip_lookup(data: pd.DataFrame, indices: list) -> list:
    """
    :return: List of tuples of unique indices
    """
    lookup = data.filter(indices).dropna()
    lookup.set_index(indices, inplace=True)
    lookup.sort_index(inplace=True)
    index_set = list(set(lookup.index.tolist()))
    return index_set

# %%
state_city_zip_lookup = get_city_state_zip_lookup(zillow_zip_data, ['State', 'City', 'ZIP'])

# %%
state_city_zip_lookup
# Out:
# [('MD', 'Swanton', 21561),
#  ('OH', 'Doylestown', 44230),
#  ('NC', 'Holly Springs', 27540),
#  ('TN', 'Morristown', 37814),
#  ('FL', 'Orlando', 32824),
#  ('KS', 'Garnett', 66032),
#  ('MO', 'Chesterfield', 63005),
#  ('AZ', 'Prescott', 86305),
#  ('NJ', 'Florence', 8518),
#  ('MI', 'Reed City', 49677),
#  ('OH', 'London', 43140),
#  ('OH', 'Warren', 44483),
#  ('OR', 'Grants Pass', 97527),
#  ('TN', 'Lookout Mountain', 37350),
#  ('IN', 'Indianapolis', 46231),
#  ('KS', 'Wamego', 66547),
#  ('VA', 'North Tazewell', 24630),
#  ('IN', 'Huntingburg', 47542),
#  ('CA', 'Big Bear City', 92314),
#  ('WA', 'Parkland', 98444),
#  ('MA', 'Newton', 2464),
#  ('NC', 'Murphy', 28906),
#  ('WI', 'Butler', 53007),
#  ('SC', 'Lake City', 29560),
#  ('NJ', 'Pilesgrove', 8098),
#  ('CO', 'Ken Caryl', 80127),
#  ('MD', 'Centreville', 21617),
#  ('WI', 'Hatley', 54440),
#  ('MA', 'Northborough', 1532),
#  ('MA', 'Millville', 1529),
#  ('MD', 'District Heights', 20747),
#  ('NC', 'Lake Lure', 28756),
#  ('IL', 'Braidwood', 60408),
#  ('GA', 'Greenville', 30222),
#  ('WI', 'Milwaukee', 53225),
#  ('UT', 'Tremonton', 84337),
#  ('NJ', 'Bethlehem', 8802),
#  ('VA', 'Axton', 24054),
#  ('CA', 'Canyon Lake', 92587),
#  ('AL', 'Phenix City', 36867),
#  ('WA', 'Port Orchard', 98367),
#  ('NY', 'Mount Ivy', 10970),
#  ('NJ', 'Villas', 8251),
#  ('SC', 'Isle of Palms', 29451),
#  ('OH', 'Kingsville', 44048),
#  ('PA', 'Pocono Pines', 18350),
#  ('HI', 'Honolulu', 96817),
#  ('TX', 'Weimar', 78962),
#  ('NC', 'Mars Hill', 28754),
#  ('FL', 'Sanford', 32773),
#  ('VA', 'Tazewell', 24651),
#  ('WV', 'Barboursville', 25504),
#  ('TX', 'Dallas', 75215),
#  ('CA', 'Frazier Park', 93225),
#  ('GA', 'Chatsworth', 30705),
#  ('VA', 'Portsmouth', 23703),
#  ('LA', 'Baton Rouge', 70814),
#  ('NY', 'Commack', 11725),
#  ('MA', 'Brookline', 2446),
#  ('GA', 'Atlanta', 30327),
#  ('NJ', 'Hardyston', 7460),
#  ('OK', 'Henryetta', 74437),
#  ('AZ', 'Thatcher', 85552),
#  ('PA', 'Philadelphia', 19153),
#  ('PA', 'Springdale', 15144),
#  ('VA', 'Hopewell', 23860),
#  ('AZ', 'Snowflake', 85937),
#  ('CA', 'San Francisco', 94132),
#  ('CT', 'Salisbury', 6068),
#  ('CA', 'Los Angeles', 91307),
#  ('LA', 'Mandeville', 70471),
#  ('MD', 'West River', 20778),
#  ('MA', 'Buckland', 1338),
#  ('IA', 'Sioux City', 51104),
#  ('OK', 'Muskogee', 74401),
#  ('TX', 'Lubbock', 79424),
#  ('WV', 'Parkersburg', 26104),
#  ('KY', 'Mount Sterling', 40353),
#  ('NY', 'New York', 11238),
#  ('LA', 'Iowa', 70647),
#  ('CA', 'Danville', 94506),
#  ('TX', 'Fort Worth', 76114),
#  ('TX', 'Georgetown', 78628),
#  ('GA', 'Buchanan', 30113),
#  ('TX', 'San Diego', 78384),
#  ('CO', 'Calhan', 80808),
#  ('CA', 'San Luis Obispo', 93401),
#  ('LA', 'Bastrop', 71220),
#  ('WI', 'Brillion', 54110),
#  ('VA', 'Henrico', 23294),
#  ('TX', 'Paige', 78659),
#  ('OH', 'De Graff', 43318),
#  ('MI', 'Lake', 49106),
#  ('ME', 'Kittery', 3905),
#  ('OH', 'Carroll', 43112),
#  ('CA', 'Bradley', 93426),
#  ('TX', 'Weslaco', 78599),
#  ('OK', 'Edmond', 73012),
#  ('CA', 'Sacramento', 95835),
#  ('TN', 'Beech Bluff', 38313),
#  ('FL', 'Riverview', 33547),
#  ('PA', 'East Petersburg', 17520),
#  ('CA', 'Costa Mesa', 92627),
#  ('IA', 'Waukee', 50263),
#  ('MO', 'Crestwood', 63126),
#  ('NM', 'Albuquerque', 87110),
#  ('NY', 'Pleasant Valley', 12569),
#  ('NC', 'Macclesfield', 27852),
#  ('FL', 'Micanopy', 32667),
#  ('WA', 'Coupeville', 98239),
#  ('CA', 'Oceanside', 92058),
#  ('TN', 'Graysville', 37338),
#  ('KY', 'Stamping Ground', 40379),
#  ('NV', 'Las Vegas', 89138),
#  ('NM', 'Los Alamos', 87544),
#  ('CA', 'Big Bear Lake', 92315),
#  ('IN', 'Remington', 47977),
#  ('PA', 'Bradfordwoods', 15015),
#  ('CA', 'Fresno', 93722),
#  ('MS', 'Jackson', 39202),
#  ('LA', 'Gueydan', 70542),
#  ('WA', 'Maple Falls', 98266),
#  ('MT', 'Frenchtown', 59834),
#  ('TX', 'Mission', 78574),
#  ('TX', 'Wichita Falls', 76305),
#  ('PA', 'Randolph', 16327),
#  ('OH', 'Union City', 45390),
#  ('NY', 'New York', 11434),
#  ('CA', 'Carlsbad', 92010),
#  ('SC', 'Batesburg-Leesville', 29006),
#  ('FL', 'Osprey', 34229),
#  ('OH', 'Green Springs', 44836),
#  ('WI', 'Allouez', 54301),
#  ('MA', 'Boxford', 1921),
#  ('AL', 'Grant', 35776),
#  ('OH', 'Brook Park', 44142),
#  ('KS', 'Udall', 67146),
#  ('IL', 'Schaumburg', 60193),
#  ('MA', 'Petersham', 1366),
#  ('FL', 'Fort Meade', 33841),
#  ('GA', 'Commerce', 30529),
#  ('CO', 'Lake George', 80827),
#  ('FL', 'Sebastian', 32958),
#  ('NC', 'Fuquay Varina', 27526),
#  ('FL', 'Orlando', 32817),
#  ('NC', 'Reidsville', 27320),
#  ('IN', 'Bunker Hill', 46914),
#  ('FL', 'Century Village', 33417),
#  ('MN', 'Brook Park', 55007),
#  ('FL', 'Navarre', 32566),
#  ('OK', 'Mounds', 74047),
#  ('IL', 'Aurora', 60506),
#  ('KS', 'Saint Marys', 66536),
#  ('MA', 'Ludlow', 1056),
#  ('MI', 'Monroe', 48161),
#  ('OH', 'Graytown', 43432),
#  ('MI', 'East Lansing', 48823),
#  ('FL', 'Anna Maria', 34216),
#  ('MI', 'Dowling', 49050),
#  ('TX', 'Kyle', 78640),
#  ('OH', 'Hebron', 43025),
#  ('TX', 'Aransas Pass', 78336),
#  ('WI', 'Spring Green', 53588),
#  ('CO', 'Byers', 80103),
#  ('MI', 'Elmira', 49730),
#  ('FL', 'Bradenton', 34203),
#  ('FL', 'Clearwater', 33755),
#  ('PA', 'Springfield', 19064),
#  ('NY', 'Pound Ridge', 10576),
#  ('NY', 'Prattsville', 12468),
#  ('OH', 'South Vienna', 45369),
#  ('TX', 'McKinney', 75070),
#  ('WI', 'Milwaukee', 53216),
#  ('WA', 'Elk', 99009),
#  ('MN', 'Lake Elmo', 55042),
#  ('TX', 'San Antonio', 78229),
#  ('CA', 'Rocklin', 95677),
#  ('FL', "Town 'n' Country", 33615),
#  ('MN', 'Annandale', 55302),
#  ('TN', 'Vonore', 37885),
#  ('NJ', 'Freehold', 7728),
#  ('TN', 'Christiana', 37037),
#  ('IL', 'Belleville', 62223),
#  ('NY', 'Saratoga Springs', 12866),
#  ('CA', 'Wasco', 93280),
#  ('CA', 'Rancho Santa Fe', 92091),
#  ('CO', 'Salida', 81201),
#  ('IN', 'Crothersville', 47229),
#  ('MA', 'Leicester', 1542),
#  ('TX', 'Lubbock', 79410),
#  ('MT', 'Hardin', 59034),
#  ('GA', 'Rome', 30165),
#  ('TN', 'Lenoir City', 37772),
#  ('IL', 'Elmwood', 61529),
#  ('TN', 'Harriman', 37748),
#  ('TN', 'Samburg', 38232),
#  ('SC', 'Lancaster', 29720),
#  ('CA', 'Santa Fe Springs', 90670),
#  ('WV', 'Martinsburg', 25403),
#  ('FL', 'Spring Hill', 34606),
#  ('PA', 'Manchester', 17404),
#  ('CA', 'Merced', 95348),
#  ('PA', 'Barrett', 18325),
#  ('MI', 'Brighton', 48116),
#  ('OR', 'Dallas', 97338),
#  ('CA', 'Silverado', 92676),
#  ('MN', 'Norwood Young America', 55368),
#  ('TN', 'Chattanooga', 37415),
#  ('TX', 'Austin', 78704),
#  ('IL', 'Des Plaines', 60018),
#  ('TX', 'Houston', 77025),
#  ('PA', 'Salisbury', 17527),
#  ('TX', 'Port Bolivar', 77650),
#  ('VA', 'Arlington', 22203),
#  ('PA', 'New Beaver', 16157),
#  ('LA', 'Hammond', 70403),
#  ('WA', 'Vancouver', 98684),
#  ('CO', 'Livermore', 80536),
#  ('SC', 'Easley', 29640),
#  ('TX', 'Fort Worth', 76123),
#  ('PA', 'West Newton', 15089),
#  ('KY', 'Boston', 40107),
#  ('AZ', 'Tucson', 85706),
#  ('OR', 'Reedsport', 97467),
#  ('SC', 'North', 29112),
#  ('IL', 'Franklin', 62638),
#  ('OR', 'Sublimity', 97385),
#  ('NY', 'Neversink', 12740),
#  ('PA', 'Penn Hills', 15147),
#  ('NY', 'Elmira', 14904),
#  ('NY', 'Scarsdale', 10583),
#  ('PA', 'Paradise', 17562),
#  ('MD', 'Whiteford', 21160),
#  ('PA', 'Penn', 15085),
#  ('IL', 'Frankfort', 60423),
#  ('FL', 'Delray Beach', 33445),
#  ('MD', 'Sparks Glencoe', 21152),
#  ('VA', 'Esmont', 22937),
#  ('NV', 'Las Vegas', 89147),
#  ('CA', 'Springville', 93265),
#  ('MD', 'Laurel', 20724),
#  ('MI', 'Buchanan', 49107),
#  ('OH', 'Clayton', 45315),
#  ('OH', 'Crown City', 45623),
#  ('MD', 'Smithsburg', 21783),
#  ('PA', 'Cumru', 19607),
#  ('NC', 'Thomasville', 27360),
#  ('UT', 'Spanish Fork', 84660),
#  ('PA', 'Riegelsville', 18077),
#  ('CO', 'Parker', 80134),
#  ('OK', 'Elgin', 73538),
#  ('CA', 'Banning', 92220),
#  ('CA', 'Signal Hill', 90755),
#  ('AR', 'Fayetteville', 72701),
#  ('NY', 'New York', 11427),
#  ('RI', 'Kingston', 2881),
#  ('NH', 'Madbury', 3823),
#  ('WI', 'Poynette', 53955),
#  ('SC', 'Roebuck', 29376),
#  ('NY', 'Nassau', 12062),
#  ('TX', 'Fort Worth', 76177),
#  ('CO', 'Pueblo', 81001),
#  ('NC', 'Sunset Beach', 28468),
#  ('WI', 'Blue Mounds', 53517),
#  ('GA', 'Columbus', 31808),
#  ('MI', 'South Boardman', 49680),
#  ('VA', 'Toano', 23168),
#  ('DC', 'Washington', 20004),
#  ('IN', 'Bremen', 46506),
#  ('MN', 'Aitkin', 56431),
#  ('FL', 'Orlando', 32806),
#  ('MI', 'Battle Creek', 49017),
#  ('TX', 'Arcola', 77583),
#  ('UT', 'Eagle Mountain', 84005),
#  ('FL', 'Big Pine Key', 33043),
#  ('NC', 'Lake Junaluska', 28745),
#  ('PA', 'Boggs', 15801),
#  ('PA', 'Dalton', 18414),
#  ('NY', 'Rocky Point', 11778),
#  ('OK', 'Oklahoma City', 73162),
#  ('NC', 'High Point', 27235),
#  ('IL', 'Norridge', 60706),
#  ('NE', 'Madison', 68748),
#  ('IL', 'Elburn', 60119),
#  ('PA', 'Pittsburgh', 15211),
#  ('IL', 'Elmhurst', 60126),
#  ('MI', 'Beaverton', 48612),
#  ('AR', 'Little Rock', 72223),
#  ('MT', 'Kalispell', 59901),
#  ('CA', 'Diamond Springs', 95619),
#  ('ME', 'Wells', 4090),
#  ('MI', 'Elsie', 48831),
#  ('PA', 'Heidelberg', 18053),
#  ('MO', 'Vandalia', 63382),
#  ('WA', 'Mossyrock', 98564),
#  ('KS', 'Syracuse', 67878),
#  ('OH', 'Genoa', 43430),
#  ('OH', 'Okeana', 45053),
#  ('WI', 'Saukville', 53080),
#  ('TX', 'San Antonio', 78254),
#  ('WA', 'Arlington', 98223),
#  ('WI', 'Wisconsin Rapids', 54494),
#  ('LA', 'Natchitoches', 71457),
#  ('NJ', 'Palmyra', 8065),
#  ('OR', 'Portland', 97236),
#  ('MO', 'Saint James', 65559),
#  ('NC', 'Richlands', 28574),
#  ('IA', 'Coon Rapids', 50058),
#  ('MI', 'Oxford', 48371),
#  ('TX', 'Abilene', 79603),
#  ('GA', 'Temple', 30179),
#  ('OK', 'Lindsay', 73052),
#  ('TX', 'Killeen', 76543),
#  ('MD', 'Chillum', 20783),
#  ('MI', 'Shelby', 48316),
#  ('TX', 'Friendswood', 77546),
#  ('NH', 'Northwood', 3261),
#  ('KY', 'Lexington', 40507),
#  ('CA', 'Eastvale', 91752),
#  ('IL', 'Harvard', 60033),
#  ('IN', 'North Manchester', 46962),
#  ('FL', 'Cedar Key', 32625),
#  ('TX', 'Dallas', 75229),
#  ('FL', 'Micco', 32976),
#  ('KY', 'Louisville', 40219),
#  ('PA', 'Harrison', 15065),
#  ('TX', 'The Woodlands', 77381),
#  ('NH', 'Hudson', 3051),
#  ('MO', 'Saint Joseph', 64506),
#  ('OH', 'Harrison', 45252),
#  ('NJ', 'Montville', 7045),
#  ('CA', 'Suisun City', 94585),
#  ('MI', 'Rochester Hills', 48309),
#  ('MA', 'Fall River', 2720),
#  ('FL', 'Lake City', 32024),
#  ('WI', 'Pell Lake', 53128),
#  ('NY', 'Greene', 13778),
#  ('ND', 'Bismarck', 58504),
#  ('GA', 'Atlanta', 30305),
#  ('TN', 'Johnson City', 37604),
#  ('OH', 'Sharonville', 45241),
#  ('TX', 'Driftwood', 78619),
#  ('TX', 'Houston', 77038),
#  ('IL', 'Chicago', 60622),
#  ('FL', 'Westchase', 33626),
#  ('NV', 'Henderson', 89074),
#  ('WI', 'Greenfield', 53228),
#  ('TX', 'Crosby', 77532),
#  ('IN', 'Gosport', 47433),
#  ('MA', 'Medfield', 2052),
#  ('IL', 'Huntley', 60142),
#  ('RI', 'Cranston', 2910),
#  ('CA', 'Temecula', 92592),
#  ('MT', 'Helena', 59601),
#  ('NJ', 'Ortley Beach', 8751),
#  ('MI', 'Berkley', 48072),
#  ('VA', 'Linden', 22642),
#  ('CO', 'Arvada', 80007),
#  ('FL', 'Tallahassee', 32304),
#  ('VA', 'Chesterfield', 23832),
#  ('GA', 'Rocky Face', 30740),
#  ('AZ', 'Glendale', 85304),
#  ('CA', 'Santa Barbara', 93110),
#  ('IN', 'Lebanon', 46052),
#  ('TX', 'Corsicana', 75110),
#  ('TN', 'Cleveland', 37311),
#  ('WI', 'Theresa', 53091),
#  ('NH', 'Strafford', 3884),
#  ('TX', 'Elgin', 78621),
#  ('TX', 'Lamesa', 79331),
#  ('IL', 'Belvidere', 61008),
#  ('CA', 'Sacramento', 95817),
#  ('CT', 'Old Saybrook', 6475),
#  ('OR', 'Salem', 97301),
#  ('ID', 'Blackfoot', 83221),
#  ('PA', 'Newtown', 19073),
#  ('PA', 'Slippery Rock', 16057),
#  ('CT', 'Plainfield', 6354),
#  ('GA', 'Carnesville', 30521),
#  ('MN', 'Duluth', 55807),
#  ('NY', 'Geneseo', 14454),
#  ('NJ', 'Gloucester', 8012),
#  ('CA', 'Grass Valley', 95949),
#  ('OH', 'Mount Vernon', 43050),
#  ('TN', 'Bulls Gap', 37711),
#  ('FL', 'Saint Augustine', 32080),
#  ('MD', 'Pylesville', 21132),
#  ('CA', 'Sunnyvale', 94085),
#  ('NJ', 'Dover', 7801),
#  ('TX', 'Houston', 77088),
#  ('ID', 'Post Falls', 83854),
#  ('TX', 'Dimmitt', 79027),
#  ('VA', 'Norfolk', 23509),
#  ('MI', 'Wheeler', 48662),
#  ('NH', 'Stratford', 3590),
#  ('WA', 'Port Angeles', 98363),
#  ('PA', 'Uniontown', 15401),
#  ('NY', 'New York', 11356),
#  ('NY', 'Johnson City', 13790),
#  ('CA', 'Carson', 90746),
#  ('IL', 'Round Lake Beach', 60073),
#  ('CA', 'Meadow Vista', 95722),
#  ('OH', 'Pemberville', 43450),
#  ('MD', 'Freeland', 21053),
#  ('TX', 'Bullard', 75757),
#  ('CA', 'San Jose', 95148),
#  ('NJ', 'Passaic', 7055),
#  ('TX', 'El Paso', 79905),
#  ('MI', 'Redford', 48239),
#  ('NY', 'Elmont', 11003),
#  ('OR', 'Astoria', 97103),
#  ('DC', 'Washington', 20015),
#  ('OH', 'Clayton', 45415),
#  ('DE', 'Lewes', 19958),
#  ('PA', 'Richmond', 16933),
#  ('CA', 'Ventura', 93004),
#  ('NC', 'Graham', 27253),
#  ('FL', 'Panama City Beach', 32407),
#  ('KS', 'Augusta', 67010),
#  ('OK', 'Oklahoma City', 73139),
#  ('MO', 'Villa Ridge', 63089),
#  ('CA', 'Los Angeles', 91604),
#  ('TX', 'Hurst', 76054),
#  ('WA', 'Buckley', 98321),
#  ('CA', 'Anaheim', 92807),
#  ('CA', 'Los Osos', 93402),
#  ('MO', 'Park Hills', 63601),
#  ('IL', 'Granite City', 62040),
#  ('NV', 'Dayton', 89403),
#  ('FL', 'Sarasota', 34238),
#  ('TN', 'Smyrna', 37167),
#  ('NJ', 'Glen Ridge', 7028),
#  ('TN', 'Chapmansboro', 37035),
#  ('ID', 'Sugar City', 83448),
#  ('FL', 'Clewiston', 33440),
#  ('LA', 'New Orleans', 70122),
#  ('PA', 'Cecil', 15055),
#  ('WI', 'Green Bay', 54229),
#  ('IL', 'Addison', 60101),
#  ('WV', 'Weirton', 26062),
#  ('TX', 'San Antonio', 78247),
#  ('PA', 'Exeter', 19606),
#  ('VA', 'Manassas', 20112),
#  ('FL', 'Inglis', 34449),
#  ('OH', 'Tallmadge', 44278),
#  ('CO', 'Denver', 80216),
#  ('MO', 'Foley', 63347),
#  ('OR', 'Portland', 97229),
#  ('MA', 'Southwick', 1077),
#  ('NC', 'Star', 27356),
#  ('CA', 'Hayward', 94544),
#  ('CO', 'Drake', 80515),
#  ('AZ', 'Mohave Valley', 86426),
#  ('FL', 'Palm Bay', 32909),
#  ('NC', 'Wilson', 27893),
#  ('MA', 'Grafton', 1536),
#  ('FL', 'Quincy', 32352),
#  ('IA', 'Saint Charles', 50240),
#  ('NJ', 'New Brunswick', 8901),
#  ('PA', 'Palmyra', 18464),
#  ('NJ', 'Waldwick', 7463),
#  ('IL', 'Aviston', 62216),
#  ('FL', 'Marianna', 32446),
#  ('FL', 'Bartow', 33830),
#  ('CO', 'Timnath', 80547),
#  ('OK', 'Adair', 74330),
#  ('GA', 'Atlanta', 30312),
#  ('TX', 'Austin', 78702),
#  ('PA', 'Forks', 18040),
#  ('IN', 'Parker City', 47368),
#  ('TX', 'Houston', 77047),
#  ('IL', 'Chicago', 60609),
#  ('MD', 'Huntingtown', 20639),
#  ('TX', 'Galveston', 77550),
#  ('OR', 'Tigard', 97223),
#  ('OH', 'Greenfield', 45123),
#  ('IN', 'Liberty', 47353),
#  ('MA', 'Northampton', 1053),
#  ('GA', 'Clayton', 30525),
#  ('CA', 'Apple Valley', 92307),
#  ('VT', 'Shrewsbury', 5738),
#  ('NC', 'Morven', 28119),
#  ('CT', 'Warren', 6754),
#  ('NY', 'Argyle', 12809),
#  ('TX', 'Streetman', 75859),
#  ('MI', 'Republic', 49879),
#  ('MA', 'Wellesley', 2482),
#  ('CA', 'Beverly Hills', 90210),
#  ('CA', 'Woodbridge', 95258),
#  ('OH', 'North Olmsted', 44070),
#  ('MI', 'Schoolcraft', 49087),
#  ('LA', 'Denham Springs', 70726),
#  ('NY', 'Oswego', 13126),
#  ('WA', 'Burien', 98166),
#  ('PA', 'Shamokin', 17860),
#  ('AR', 'Pottsville', 72858),
#  ('TN', 'Newport', 37821),
#  ('GA', 'McCaysville', 30555),
#  ('NH', 'Haverhill', 3774),
#  ('IN', 'Owensville', 47665),
#  ('MN', 'New Prague', 56071),
#  ('NC', 'Sugar Grove', 28679),
#  ('IL', 'Sheridan', 60551),
#  ('WI', 'Madison', 53716),
#  ('WI', 'Caledonia', 53126),
#  ('CA', 'Wrightwood', 92397),
#  ('WI', 'Balsam Lake', 54810),
#  ('SC', 'Westminster', 29693),
#  ('VT', 'Bristol', 5443),
#  ('NC', 'Garner', 27529),
#  ('IL', 'Rochester', 62563),
#  ('OK', 'Altus', 73521),
#  ('PA', 'Scottdale', 15683),
#  ('PA', 'Bradford', 16701),
#  ('OR', 'Sandy', 97055),
#  ('CA', 'Friant', 93626),
#  ('FL', 'Rotonda West', 33947),
#  ('MN', 'Maplewood', 55109),
#  ('TX', 'Celina', 75009),
#  ('IA', 'Hazleton', 50641),
#  ('NJ', 'Union City', 7087),
#  ('PA', 'Rayne', 15747),
#  ('NH', 'North Hampton', 3862),
#  ('NJ', 'Jackson', 8527),
#  ('NY', 'Albertson', 11507),
#  ('NY', 'Stockbridge', 13409),
#  ('TX', 'Dumas', 79029),
#  ('MA', 'Foxborough', 2035),
#  ('CA', 'Menifee', 92584),
#  ('CA', 'San Jose', 95127),
#  ('CA', 'Los Angeles', 90067),
#  ('PA', 'Duryea', 18642),
#  ('KS', 'Topeka', 66605),
#  ('CA', 'American Canyon', 94503),
#  ('FL', 'Lantana', 33462),
#  ('NY', 'Miller Place', 11764),
#  ('MN', 'Greenfield', 55357),
#  ('PA', 'Union', 17864),
#  ('TN', 'Knoxville', 37924),
#  ('OK', 'Slaughterville', 73051),
#  ('NY', 'Dobbs Ferry', 10522),
#  ('VA', 'Union Hall', 24176),
#  ('MS', 'Columbia', 39429),
#  ('IN', 'Brownsburg', 46112),
#  ('VA', 'Quinton', 23141),
#  ('MA', 'Middleborough', 2346),
#  ('NY', 'Esperance', 12066),
#  ('MA', 'Westford', 1886),
#  ('MN', 'Pine City', 55063),
#  ('CO', 'Johnstown', 80534),
#  ('NY', 'Windham', 12496),
#  ('MI', 'Frenchtown', 48162),
#  ('PA', 'Union', 16844),
#  ('MI', 'Berrien Center', 49102),
#  ('CA', 'North Tustin', 92705),
#  ('MA', 'Auburn', 1501),
#  ('CA', 'West Covina', 91792),
#  ('CA', 'Victorville', 92392),
#  ('NM', 'Santa Fe', 87508),
#  ('UT', 'Washington Terrace', 84405),
#  ('CT', 'Waterbury', 6706),
#  ('OH', 'Cortland', 44410),
#  ('NY', 'Macedon', 14502),
#  ('GA', 'Duluth', 30096),
#  ('CA', 'Artesia', 90701),
#  ('TX', 'Dickinson', 77539),
#  ('HI', 'Captain Cook', 96704),
#  ('TN', 'Milan', 38358),
#  ('OR', 'Boring', 97009),
#  ('SC', 'Aiken', 29801),
#  ('TX', 'Conroe', 77304),
#  ('FL', 'Marianna', 32448),
#  ('MD', 'Kettering', 20774),
#  ('IA', 'Anamosa', 52205),
#  ('IL', 'Collinsville', 62234),
#  ('TX', 'San Antonio', 78256),
#  ('AZ', 'Phoenix', 85008),
#  ('CA', 'Kingsburg', 93631),
#  ('TX', 'McAllen', 78504),
#  ('CO', 'Denver', 80207),
#  ('SC', 'Summerton', 29148),
#  ('NC', 'Goldsboro', 27530),
#  ('CA', 'Bakersfield', 93301),
#  ('IL', 'Crest Hill', 60403),
#  ('TN', 'Clinton', 37716),
#  ('FL', 'Port Saint Lucie', 34984),
#  ('VA', 'Lovingston', 22949),
#  ('GA', 'Lawrenceville', 30043),
#  ('MI', 'Edwardsburg', 49112),
#  ('MT', 'Great Falls', 59405),
#  ('NJ', 'Plainfield', 7063),
#  ('TX', 'San Angelo', 76903),
#  ('NC', 'Mount Airy', 27030),
#  ('KY', 'Louisville', 40205),
#  ('OH', 'Columbus', 43240),
#  ('MN', 'Ogilvie', 56358),
#  ('NY', 'Heuvelton', 13654),
#  ('ID', 'Mountain Home', 83647),
#  ('NJ', 'Carlstadt', 7072),
#  ('ID', 'Glenns Ferry', 83623),
#  ('OH', 'New Concord', 43762),
#  ('WI', 'Elroy', 53929),
#  ('NC', 'Kings Mountain', 28086),
#  ('NY', 'Orangetown', 10968),
#  ('TX', 'Nocona', 76255),
#  ('IA', 'Norwalk', 50211),
#  ('FL', 'Summerland Key', 33042),
#  ('ID', 'Boise', 83706),
#  ('CA', 'Fawnskin', 92333),
#  ('TX', 'Austin', 78741),
#  ('UT', 'Cedar City', 84720),
#  ('VA', 'Dumfries', 22026),
#  ('KY', 'Whitesville', 42378),
#  ('IL', 'Chicago', 60632),
#  ('CO', 'Centennial', 80122),
#  ('IN', 'Saint John', 46373),
#  ('NJ', 'Manasquan', 8736),
#  ('AL', 'Cedar Bluff', 35959),
#  ('VA', 'Chesapeake', 23325),
#  ('CA', 'Sloughhouse', 95683),
#  ('HI', 'Makawao', 96768),
#  ('NJ', 'Ocean', 8758),
#  ('OH', 'Bowling Green', 43402),
#  ('PA', 'Albion', 16401),
#  ('FL', 'Shady Hills', 34610),
#  ('UT', 'Blanding', 84511),
#  ('IL', 'Oak Park', 60301),
#  ('WI', 'Sturtevant', 53177),
#  ('CO', 'Castle Rock', 80109),
#  ('MI', 'Spring Arbor', 49283),
#  ('OH', 'Cincinnati', 45238),
#  ('TX', 'Rockwall', 75087),
#  ('IL', 'La Salle', 61301),
#  ('AZ', 'Tucson', 85745),
#  ('IA', 'Coggon', 52218),
#  ('SD', 'Baltic', 57003),
#  ('AZ', 'Amado', 85645),
#  ('SC', 'Myrtle Beach', 29577),
#  ('WA', 'White Salmon', 98672),
#  ('MA', 'Windsor', 1270),
#  ('AZ', 'Lake Havasu City', 86403),
#  ('FL', 'Temple Terrace', 33637),
#  ('IN', 'Nappanee', 46550),
#  ('AL', 'Kinston', 36453),
#  ('MI', 'Ferndale', 48220),
#  ('TX', 'Brazoria', 77422),
#  ('PA', 'North Woodbury', 16662),
#  ('TX', 'Garland', 75042),
#  ('TN', 'Germantown', 38139),
#  ('FL', 'Pompano Beach', 33069),
#  ('KS', 'De Soto', 66018),
#  ('GA', 'Rincon', 31326),
#  ('NY', 'Lockport', 14094),
#  ('FL', 'Graceville', 32440),
#  ('OH', 'Parma', 44134),
#  ('WA', 'Seattle', 98105),
#  ('SC', 'Charleston', 29403),
#  ('IL', 'Poplar Grove', 61065),
#  ('AZ', 'Mesa', 85201),
#  ('IL', 'Coal Valley', 61240),
#  ('OH', 'Kinsman', 44428),
#  ('VA', 'Henrico', 23229),
#  ('CO', 'Bayfield', 81122),
#  ('NY', 'Lansing', 14882),
#  ('AR', 'Atkins', 72823),
#  ('OK', 'Tulsa', 74146),
#  ('NC', 'Holden Beach', 28462),
#  ('TN', 'Sevierville', 37764),
#  ('MA', 'Hopedale', 1747),
#  ('CO', 'Aurora', 80013),
#  ('MI', 'Dexter', 48130),
#  ('OH', 'Castalia', 44824),
#  ('WI', 'Prescott', 54021),
#  ('WI', 'Oconto Falls', 54154),
#  ('IL', 'Lerna', 62440),
#  ('CA', 'San Jose', 95134),
#  ('TX', 'North Richland Hills', 76180),
#  ('NY', 'Albany', 12203),
#  ('KY', 'Crestwood', 40014),
#  ('MD', 'Jarrettsville', 21084),
#  ('WA', 'Bremerton', 98311),
#  ('TN', 'Knoxville', 37917),
#  ('GA', 'Columbus', 31909),
#  ('NY', 'New York', 10306),
#  ('CA', 'Albany', 94706),
#  ('MI', 'Honor', 49640),
#  ('VA', 'Hampton', 23664),
#  ('NJ', 'High Bridge', 8829),
#  ('IN', 'Columbus', 47203),
#  ('AL', 'Glencoe', 35905),
#  ('OH', 'Gallipolis', 45614),
#  ('NM', 'Bloomfield', 87413),
#  ('FL', 'Sebring', 33872),
#  ('IA', 'Davenport', 52803),
#  ('PA', 'Scranton', 18504),
#  ('TX', 'Cypress', 77433),
#  ('NM', 'Santa Rosa', 88435),
#  ('CO', 'Laporte', 80535),
#  ('ME', 'Buxton', 4093),
#  ('NC', 'Waynesville', 28785),
#  ('NY', 'New York', 10012),
#  ('MI', 'Clarkston', 48346),
#  ('IL', 'Atlanta', 61723),
#  ('CA', 'Los Alamitos', 90720),
#  ('MD', 'Deal Island', 21821),
#  ('CA', 'Chino Hills', 91709),
#  ('MA', 'Lincoln', 1773),
#  ('FL', 'Eastpoint', 32328),
#  ('CA', 'Kentfield', 94904),
#  ('MN', 'Saginaw', 55779),
#  ('IN', 'Fort Wayne', 46809),
#  ('WA', 'Shoreline', 98177),
#  ('MN', 'Hinckley', 55037),
#  ('SC', 'Bonneau', 29431),
#  ('OH', 'Macedonia', 44056),
#  ('PA', 'Toboyne', 17006),
#  ('PA', 'Nescopeck', 18635),
#  ('PA', 'Lower Tyrone', 15428),
#  ('IL', 'Evanston', 60202),
#  ('MI', 'Kingsley', 49649),
#  ('DE', 'Milton', 19968),
#  ('HI', 'Kaaawa', 96730),
#  ('KS', 'Arma', 66712),
#  ('FL', 'Mount Dora', 32757),
#  ('SC', 'Greenwood', 29649),
#  ('NY', 'Day', 12835),
#  ('NJ', 'Ewing', 8638),
#  ('KS', 'Wichita', 67204),
#  ('NC', 'Monroe', 28112),
#  ('NJ', 'Sea Isle City', 8243),
#  ('NJ', 'Wanaque', 7465),
#  ('WA', 'Spokane', 99217),
#  ('NC', 'Cameron', 28326),
#  ('FL', 'Gulf Breeze', 32561),
#  ('NY', 'Perinton', 14450),
#  ('NJ', 'Atlantic Highlands', 7716),
#  ('KY', 'Elizabethtown', 42701),
#  ('PA', 'Warwick', 17543),
#  ('ID', 'Salmon', 83467),
#  ('TN', 'Halls', 38040),
#  ('TX', 'Huntsville', 77340),
#  ('PA', 'Lower Windsor', 17368),
#  ('CA', 'Tollhouse', 93667),
#  ('IL', 'Chatsworth', 60921),
#  ('NJ', 'Byram', 7821),
#  ('TX', 'Austin', 78748),
#  ('NJ', 'East Greenwich', 8061),
#  ('TX', 'Canyon Lake', 78133),
#  ('IN', 'Terre Haute', 47805),
#  ('OH', 'Oak Harbor', 43449),
#  ('PA', 'Dickson City', 18519),
#  ('KY', 'Frankfort', 40601),
#  ('DE', 'Wilmington', 19802),
#  ('MN', 'Hayfield', 55940),
#  ('WA', 'Edmonds', 98020),
#  ('MA', 'Oakham', 1068),
#  ('MD', 'Frostburg', 21532),
#  ('NJ', 'North Haledon', 7508),
#  ('OK', 'Pettit', 74451),
#  ('WI', 'Lancaster', 53813),
#  ('IA', 'Des Moines', 50311),
#  ('ID', 'Kuna', 83634),
#  ('FL', 'Fort Walton Beach', 32548),
#  ('NC', 'Smithfield', 27577),
#  ('CA', 'Pomona', 91766),
#  ('TX', 'Richmond', 77407),
#  ('AZ', 'Phoenix', 85331),
#  ('WA', 'Pacific', 98047),
#  ('NJ', 'Far Hills', 7931),
#  ('MI', 'Union City', 49094),
#  ('TX', 'Madisonville', 77864),
#  ('SC', 'Hollywood', 29449),
#  ('OH', 'Swanton', 43558),
#  ('WV', 'Salem', 26426),
#  ('TX', 'Sugar Land', 77478),
#  ('WI', 'Saint Germain', 54558),
#  ('MA', 'Townsend', 1474),
#  ('FL', 'Pompano Beach', 33060),
#  ('NY', 'Minisink', 10998),
#  ('NY', 'New York', 11230),
#  ('GA', 'Locust Grove', 30248),
#  ('PA', 'Coolbaugh', 18346),
#  ('MA', 'Hampden', 1036),
#  ('IL', 'Gibson City', 60936),
#  ('IN', 'Pendleton', 46064),
#  ('OH', 'Springfield', 45504),
#  ('IN', 'Milltown', 47145),
#  ('WA', 'Bellingham', 98225),
#  ('WA', 'Seattle', 98102),
#  ('GA', 'Silver Creek', 30173),
#  ('NC', 'Stallings', 28104),
#  ('NH', 'Litchfield', 3052),
#  ('WI', 'Reeseville', 53579),
#  ('AZ', 'Mesa', 85208),
#  ('CA', 'Atwater', 95301),
#  ('FL', 'Saint Petersburg', 33704),
#  ('MN', 'Hanover', 55341),
#  ('OH', 'Roaming Shores', 44084),
#  ('MI', 'Scottville', 49454),
#  ('MN', 'West Saint Paul', 55118),
#  ('NE', 'Omaha', 68118),
#  ('WA', 'Wenatchee', 98801),
#  ('WI', 'Kenosha', 53142),
#  ('PA', 'Lower Merion', 19004),
#  ('IN', 'Indianapolis', 46204),
#  ('NE', 'Lincoln', 68524),
#  ('CA', 'Shingle Springs', 95682),
#  ('AR', 'Hackett', 72937),
#  ('CA', 'San Ramon', 94582),
#  ('FL', 'Crystal River', 34428),
#  ('MO', 'Cleveland', 64734),
#  ('MI', 'Gwinn', 49841),
#  ('IL', 'Momence', 60954),
#  ('MI', 'Sparta', 49345),
#  ('NY', 'Massena', 13662),
#  ('OH', 'Cleveland', 44106),
#  ('OH', 'Lisbon', 44432),
#  ('OK', 'Temple', 73568),
#  ('VA', 'Cloverdale', 24077),
#  ('WA', 'Fox Island', 98333),
#  ('NJ', 'Edison', 8820),
#  ('CA', 'Los Angeles', 90017),
#  ('NY', 'Ballston', 12019),
#  ('CA', 'Stockton', 95207),
#  ('CA', 'El Cerrito', 94530),
#  ('NJ', 'Neptune', 7753),
#  ('NY', 'Holland', 14080),
#  ('NC', 'Whittier', 28789),
#  ('NJ', 'Highland Park', 8904),
#  ('MO', 'Jefferson City', 65109),
#  ('CT', 'Washington', 6793),
#  ('GA', 'Dalton', 30721),
#  ('FL', 'Ellenton', 34222),
#  ('NY', 'New York', 10005),
#  ('TX', 'Beaumont', 77703),
#  ('WV', 'Charleston', 25304),
#  ('CA', 'Long Beach', 90810),
#  ('IL', 'Yorkville', 60512),
#  ('IL', 'Bloomington', 61704),
#  ('NY', 'Barker', 13862),
#  ('NC', 'Advance', 27006),
#  ('TX', 'Holland', 76534),
#  ('NY', 'De Witt', 13214),
#  ('OR', 'Gold Beach', 97444),
#  ('NY', 'New York', 10470),
#  ('VT', 'Wallingford', 5773),
#  ('TX', 'Gonzales', 78629),
#  ('MD', 'Temple Hills', 20748),
#  ('GA', 'Cartersville', 30120),
#  ('FL', 'Deerfield Beach', 33442),
#  ('TN', 'Memphis', 38128),
#  ('NC', 'Charlotte', 28262),
#  ('MA', 'Worcester', 1604),
#  ('CT', 'Glastonbury', 6073),
#  ('NY', 'Clarkstown', 10994),
#  ('OK', 'Cookson', 74962),
#  ('OK', 'Chandler', 74834),
#  ('MO', 'Kirkwood', 63122),
#  ('MS', 'Duck Hill', 38925),
#  ('PA', 'Clinton', 16056),
#  ('NY', 'Somers', 10536),
#  ('CT', 'Ledyard', 6335),
#  ('SC', 'Columbia', 29201),
#  ('ME', 'Shapleigh', 4076),
#  ('TX', 'Poth', 78147),
#  ('VA', 'Fairfax', 22031),
#  ('CA', 'Los Angeles', 91406),
#  ('PA', 'Park Forest Village', 16803),
#  ('TN', 'Lafayette', 37083),
#  ('MI', 'Hartford', 49057),
#  ('WA', 'Tieton', 98947),
#  ('NJ', 'Newton', 7860),
#  ('IL', 'Champaign', 61822),
#  ('MA', 'Lowell', 1850),
#  ('LA', 'Springhill', 71075),
#  ('WA', 'Steilacoom', 98388),
#  ('NC', 'Winston-Salem', 27106),
#  ('PA', 'Plum', 15239),
#  ('MA', 'Chatham', 2633),
#  ('NY', 'White Plains', 10606),
#  ('NY', 'Clifton Springs', 14432),
#  ('MD', 'Ashton', 20861),
#  ('NC', 'Southern Pines', 28387),
#  ('VA', 'Troutville', 24175),
#  ('TX', 'Austin', 78723),
#  ('KY', 'Bloomfield', 40008),
#  ('NH', 'Bath', 3740),
#  ('MO', 'Parkville', 64152),
#  ('NJ', 'Rumson', 7760),
#  ('MD', 'Annapolis', 21409),
#  ('CO', 'Allenspark', 80510),
#  ('NJ', 'Upper Freehold', 8514),
#  ('CT', 'Cheshire', 6410),
#  ('MA', 'Hingham', 2043),
#  ('FL', 'Fort Pierce', 34982),
#  ('OR', 'Newport', 97366),
#  ('TN', 'Kingsport', 37665),
#  ('TN', 'Prospect', 38477),
#  ('IL', 'Onarga', 60955),
#  ('OH', 'Canton', 44707),
#  ('OH', 'Cincinnati', 45220),
#  ('PA', 'Bristol', 19007),
#  ('IL', 'Galesburg', 61401),
#  ('MA', 'Cambridge', 2142),
#  ('OH', 'Akron', 44305),
#  ('VA', 'Ringgold', 24586),
#  ('MI', 'Saranac', 48881),
#  ('GA', 'Clermont', 30527),
#  ('MN', 'Le Sueur', 56058),
#  ('PA', 'Coolspring', 16137),
#  ('MA', 'Barnstable', 2635),
#  ('MD', 'Walkersville', 21793),
#  ('PA', 'Damascus', 18405),
#  ('NC', 'Boiling Spring Lakes', 28461),
#  ('OK', 'Roland', 74954),
#  ('WA', 'Waller', 98443),
#  ('OR', 'North Plains', 97133),
#  ('TN', 'Franklin', 37069),
#  ('CA', 'Kings Beach', 96143),
#  ('NY', 'Shelter Island', 11964),
#  ('IL', 'Washington', 61571),
#  ('OH', 'Berlin Center', 44401),
#  ('FL', 'Hialeah', 33010),
#  ('TX', 'Burkburnett', 76354),
#  ('IL', 'Naperville', 60563),
#  ('NY', 'Smithtown', 11787),
#  ('TX', 'Willis', 77318),
#  ('VA', 'Herndon', 20170),
#  ('VT', 'Northfield', 5663),
#  ('NY', 'New York', 11223),
#  ('NY', 'Locke', 13092),
#  ('MN', 'Litchfield', 55355),
#  ('PA', 'Mc Donald', 15057),
#  ('UT', 'La Verkin', 84745),
#  ('TX', 'Fort Worth', 76131),
#  ('CA', 'Irvine', 92612),
#  ('WA', 'La Center', 98629),
#  ('CA', 'San Bruno', 94066),
#  ('NY', 'Middlebury', 14591),
#  ('IL', 'Glen Carbon', 62034),
#  ('FL', 'Saint Petersburg', 33715),
#  ('MS', 'Natchez', 39120),
#  ('OH', 'Milford', 45150),
#  ('OH', 'Reading', 45215),
#  ('CA', 'Redondo Beach', 90278),
#  ('NE', 'Omaha', 68111),
#  ('VA', 'Mount Vernon', 22309),
#  ('OK', 'Tulsa', 74128),
#  ('TX', 'Houston', 77060),
#  ('MI', 'Flat Rock', 48134),
#  ('ID', 'Boise', 83712),
#  ('TX', 'Hubbard', 76648),
#  ('CO', 'Colorado Springs', 80906),
#  ('IA', 'Slater', 50244),
#  ('IA', 'Walker', 52352),
#  ('IL', 'Elgin', 60120),
#  ('KS', 'Hoisington', 67544),
#  ('VA', 'Fishersville', 22939),
#  ('NY', 'Dayton', 14138),
#  ('NY', 'Nedrow', 13120),
#  ('CA', 'Firebaugh', 93622),
#  ('NJ', 'Buena Vista', 8310),
#  ('GA', 'Tucker', 30084),
#  ('CA', 'San Jose', 95112),
#  ('NV', 'Sparks', 89441),
#  ('TX', 'Humble', 77338),
#  ('MS', 'Bogue Chitto', 39629),
#  ('CA', 'Los Angeles', 90038),
#  ('MT', 'Bonner', 59823),
#  ('MN', 'Minneapolis', 55401),
#  ('CA', 'Stockton', 95212),
#  ('NC', 'Magnolia', 28453),
#  ('PA', 'Port Carbon', 17965),
#  ('HI', 'Kihei', 96753),
#  ('WA', 'Kent', 98042),
#  ('GA', 'Hull', 30646),
#  ('PA', 'Littlestown', 17340),
#  ('MN', 'Cottonwood', 56229),
#  ('SC', 'Six Mile', 29682),
#  ('NY', 'New York', 11419),
#  ('NY', 'Ramapo', 10901),
#  ('WV', 'Coal Fork', 25306),
#  ('CA', 'Palmdale', 93552),
#  ('MN', 'Cushing', 56443),
#  ('TN', 'Grandview', 37337),
#  ('CT', 'Niantic', 6357),
#  ('IA', 'Ely', 52227),
#  ('MA', 'Mansfield', 2048),
#  ('MI', 'Montrose', 48457),
#  ('PA', 'Greenwood', 17846),
#  ('FL', 'Fort Myers', 33908),
#  ('FL', 'Ponte Vedra', 32081),
#  ('UT', 'South Jordan', 84009),
#  ('MO', 'Ashland', 65010),
#  ('ID', 'Ammon', 83406),
#  ('FL', 'Vero Beach', 32960),
#  ('PA', 'Perryopolis', 15473),
#  ('GA', 'Waverly Hall', 31829),
#  ('AZ', 'Phoenix', 85045),
#  ('CA', 'Castro Valley', 94546),
#  ...]

# %%
def set_geo_indices(data: pd.DataFrame, indices: list) -> pd.DataFrame:
    data.set_index(indices, inplace=True)
    data.sort_index(inplace=True)
    return data

# %%
zillow_zip_data = set_geo_indices(zillow_zip_data, ['State', 'City', 'ZIP', 'Date'])

# %%
zillow_zip_data.head()
# Out:
#                                   PriceToRentRatio_AllHomes  ZRI_AllHomes  \
# State City      ZIP   Date
# AK    Anchorage 99501 2011-01-31                      13.44           NaN
#                       2011-02-28                      12.60           NaN
#                       2011-03-31                      11.79        1717.0
#                       2011-04-30                      11.69        1737.0
#                       2011-05-31                      11.75        1730.0
#
#                                   ZriPerSqft_AllHomes  \
# State City      ZIP   Date
# AK    Anchorage 99501 2011-01-31                  NaN
#                       2011-02-28                  NaN
#                       2011-03-31                1.390
#                       2011-04-30                1.436
#                       2011-05-31                1.460
#
#                                   Zri_SingleFamilyResidenceRental
# State City      ZIP   Date
# AK    Anchorage 99501 2011-01-31                              NaN
#                       2011-02-28                              NaN
#                       2011-03-31                           1789.0
#                       2011-04-30                           1803.0
#                       2011-05-31                           1815.0

# %%
def get_zip_feature_aggregation(data: pd.DataFrame, indices: list) -> pd.DataFrame:
    """
    :return: Aggregates the features by year for each level of the index
    """
    data_aggregate = pd.DataFrame()

    for i in range(0, len(indices)):
        single_zip_df: pd.DataFrame = data.xs([indices[i][0], indices[i][1], indices[i][2]], level=['State', 'City', 'ZIP'])
        single_zip_df.fillna(method='bfill', inplace=True)

        if single_zip_df.isna().values.any() == False:
            single_zip_df = single_zip_df.resample('A').mean()
            single_zip_df = single_zip_df.add_prefix('AVG_')
            single_zip_df.set_index(single_zip_df.index.year, inplace=True)
            single_zip_df.reset_index(inplace=True)
            single_zip_df.insert(0, "State", indices[i][0])
            single_zip_df.insert(1, 'City', indices[i][1])
            single_zip_df.insert(2, 'ZIP', indices[i][2])
            data_aggregate = data_aggregate.append(single_zip_df, ignore_index=True)
        else:
            print('DROPPED:', 'ZIP:', indices[i][2], single_zip_df.columns[single_zip_df.isna().any()].tolist(), '\n')

    return data_aggregate

# %%
zillow_zip_agg = get_zip_feature_aggregation(zillow_zip_data, state_city_zip_lookup)
# Out:
# /anaconda/envs/CIS600/lib/python3.7/site-packages/pandas/core/frame.py:4034: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   downcast=downcast, **kwargs)
# DROPPED: ZIP: 66032 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 49677 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 47542 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 54440 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 28756 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 24054 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 8251 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 78962 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 28754 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 75215 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 74437 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 51104 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 40353 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 11238 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 70647 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 76114 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 78384 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 93401 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 71220 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 49106 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 78599 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 27852 ['ZRI_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 37338 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 47977 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 39202 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 70542 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 78574 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 16327 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 67146 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 30529 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 55007 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 78336 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 53588 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 49730 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 12468 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 78229 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 81201 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 79410 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 59034 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 38232 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 77025 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 40107 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 29112 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 62638 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 49107 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 45623 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 2881 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 76177 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 53517 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 49680 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 20004 ['Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 56431 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 77583 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 33043 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 28745 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 15801 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 18414 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 11778 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 68748 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 48612 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 59901 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 4090 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 63382 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 67878 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 53080 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 71457 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 50058 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 73052 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 77546 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 46962 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 32976 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 64506 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 45252 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 45241 ['ZRI_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 78619 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 77038 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 77532 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 47433 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 59601 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 93110 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 53091 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 79331 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 16057 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 14454 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 37711 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 77088 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 79027 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 48662 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 43450 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 75757 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 7055 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 79905 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 97103 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 19958 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 63601 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 54229 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 27356 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 27893 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 50240 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 18464 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 32446 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 77047 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 77550 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 45123 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 30525 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 5738 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 75859 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 49879 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 49087 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 70726 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 13126 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 17860 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 37821 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 30555 ['PriceToRentRatio_AllHomes']
# DROPPED: ZIP: 47665 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 60551 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 53126 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 54810 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 62563 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 33947 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 50641 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 15747 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 13409 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 90067 ['Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 11764 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 17864 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 24176 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 39429 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 55063 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 12496 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 49102 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 44410 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 96704 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 77304 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 52205 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 78256 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 29148 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 22949 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 49112 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 76903 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 83623 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 43762 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 53929 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 28086 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 35959 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 96768 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 43402 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 84511 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 60301 ['ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 49283 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 61301 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 36453 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 77422 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 16662 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 75042 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 66018 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 14094 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 61240 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 81122 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 14882 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 54154 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 62440 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 76180 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 37917 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 49640 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 45614 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 18504 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 88435 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 4093 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 10012 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 61723 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 21821 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 1773 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 32328 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 55037 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 15428 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 19968 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 29649 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 8243 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 14450 ['ZRI_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 83467 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 38040 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 77340 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 47805 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 18519 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 53813 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 77407 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 49094 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 26426 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 77478 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 54558 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 47145 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 53579 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 49454 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 64734 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 49841 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 73568 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 90017 ['Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 14080 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 6793 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 77703 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 25304 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 60512 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 61704 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 13862 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 97444 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 5773 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 78629 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 74962 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 74834 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 38925 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 16056 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 4076 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 78147 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 16803 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 37083 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 71075 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 2633 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 28387 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 40008 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 64152 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 60955 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 44707 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 45220 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 61401 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 2142 ['Zri_SingleFamilyResidenceRental']
# DROPPED: ZIP: 24586 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 48881 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 30527 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 16137 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 18405 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 11964 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 61571 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 44401 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 76354 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 77318 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 5663 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 76131 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 14591 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 77060 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 76648 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 67544 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 39629 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 96753 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 56229 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 25306 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 37337 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 33908 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 31768 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 49234 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 27890 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 81435 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 32442 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 54311 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 38361 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 48650 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 78730 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 77019 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 2568 ['Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 44714 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 45213 ['ZRI_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 25015 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 70783 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 44662 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 49780 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 49721 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 76569 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 29487 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 66860 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 62326 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 70592 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 54521 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 28669 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 44481 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 77069 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 18431 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 37381 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 76470 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 49098 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 72560 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 45807 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 92108 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 39654 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 32063 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 49829 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 5667 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 99402 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 39667 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 29936 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 18801 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 79035 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 75975 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 13421 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 46310 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 11102 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 45202 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 11955 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 55956 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 6039 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 2109 ['Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 4222 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 85925 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 78408 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 95328 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 46391 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 43512 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 77082 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 70446 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 77447 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 32767 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 7074 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 71203 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 46278 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 13783 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 10032 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 67017 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 54614 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 74653 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 67951 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 50428 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 76084 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 81101 ['ZRI_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 24523 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 10075 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 39476 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 62094 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 78216 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 14063 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 2879 ['ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 54217 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 49259 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 54941 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 29047 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 30363 ['Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 14569 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 55965 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 75763 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 2832 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 55790 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 54981 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 76227 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 48632 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
# DROPPED: ZIP: 35757 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 14070 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 2554 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 3082 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 46613 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 80442 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 28043 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 27371 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 38311 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 16125 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 77386 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 81657 ['Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 23086 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 76301 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 16249 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 20135 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 53944 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 75143 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 49096 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 49080 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 76225 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 50651 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 55771 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 79036 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 77414 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 77577 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 16316 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 75202 ['Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 38852 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 2642 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 97102 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 28643 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 28352 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 87532 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 12051 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 48028 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 76111 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 55748 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 28636 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 13833 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 13456 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 44811 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 46371 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 53002 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 35097 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 54107 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 53507 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 48877 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 78207 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 46742 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 11963 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 24340 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 99603 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 10462 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 54950 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 72662 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 24330 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 99901 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 17824 ['ZRI_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 79407 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 77346 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 75209 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 11944 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 49322 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 76112 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 77450 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 38260 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 78572 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 38462 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 70301 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 8750 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 43522 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 98635 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 17801 ['ZRI_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 14530 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 61572 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 13746 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 79412 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 44646 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 35150 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 71461 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 34104 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 37738 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 24078 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 77027 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 38560 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 44406 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 1904 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 12442 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 56444 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 49349 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 76078 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 53818 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 83873 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 16023 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 16059 ['ZRI_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 18656 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 55972 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 49015 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 5149 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 13068 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 29107 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 63133 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 30436 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 42442 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 78252 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 77531 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 79601 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 64504 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 56017 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 46392 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 77032 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 14506 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
# DROPPED: ZIP: 87010 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 54612 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 37091 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 16301 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 85306 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 83845 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 3031 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 61448 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 98844 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 49307 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 77090 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 49655 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 45865 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 89048 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 11354 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 56096 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 40117 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 25442 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 39208 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 10526 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 11717 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 49753 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 46733 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 50210 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 96708 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 50106 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 24095 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 56088 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 7002 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 25159 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 53561 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 45885 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 77320 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 13903 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 77041 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 28344 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 11953 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 77477 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 43569 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 44050 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 49706 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 7029 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 49402 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 76071 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 49712 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 89411 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 64153 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 77545 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 24055 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 70535 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 13334 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 44452 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 37766 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 77563 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 70506 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 92391 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 16156 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 5457 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 76901 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 77523 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 97883 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 14837 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 99403 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 98620 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 35971 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 77054 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 49689 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 59860 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 48436 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 42025 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 11949 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 54601 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 71463 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 11786 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 77803 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 33857 ['Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 76524 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 19966 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 59864 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 70380 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 24271 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 15946 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 16617 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 18510 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 14733 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 10010 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 77708 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 67455 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 35981 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 71023 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 54115 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 65081 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 28630 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 70437 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 49090 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 16914 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 78160 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 78750 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 63072 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 47803 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 50469 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 8247 ['ZRI_AllHomes']
#
# DROPPED: ZIP: 70450 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 45804 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 34481 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 45233 ['ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 13476 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 93101 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 46975 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 11719 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 33922 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 61870 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 55709 ['PriceToRentRatio_AllHomes']
# DROPPED: ZIP: 79370 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 8403 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 85210 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 54868 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 66749 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 44840 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 45002 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 10003 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 16229 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 49885 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 56628 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 3071 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 1255 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 7310 ['Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 48166 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 77504 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 11796 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 65441 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 56007 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 35646 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 22443 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 49659 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 16314 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 76577 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 49631 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 29501 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 39701 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 32162 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 3086 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 49309 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 49033 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 48422 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 61755 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 77062 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 46574 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 98569 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 85938 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 75702 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 76633 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 56544 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 83211 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 12463 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 96097 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 51347 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 70777 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 30537 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 77514 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 95033 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 13440 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 18847 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 84049 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 51575 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 90274 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 14779 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 78732 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 77013 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 71055 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 44708 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 70427 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 76205 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 94108 ['Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 33109 ['PriceToRentRatio_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 97918 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 78602 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 78620 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 52151 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 61747 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 11740 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 77071 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 57018 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 47265 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 79110 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 82930 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 82513 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 39092 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 54166 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 45895 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 65565 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 7105 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 12804 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 71251 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 70548 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 29550 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 50125 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 85042 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 13424 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 47371 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# ...
#
# DROPPED: ZIP: 75089 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 24137 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 53570 ['ZriPerSqft_AllHomes']
# DROPPED: ZIP: 29162 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 43080 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 11782 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 77835 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 59474 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 83313 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 62360 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 53573 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 50166 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 83210 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 40385 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 17237 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 65584 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 60146 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 67665 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 78368 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 60145 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 13748 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 89029 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 55971 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 55923 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 55912 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 35741 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 77571 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 44657 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 11739 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 77303 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 85029 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 78503 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 33953 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 85337 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 48861 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 54448 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 77351 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 47451 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 11941 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 96761 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 49028 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 53035 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 46510 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 2892 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 82935 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 3580 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 16116 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 28371 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 40143 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 11216 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 35010 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 48054 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 38901 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 75709 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 10007 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 24092 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 77489 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 96064 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 38201 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 43952 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 45764 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 55949 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 62467 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 83335 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 43149 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 28673 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 29360 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 53118 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 74445 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 62568 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 77008 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 44813 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 24184 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 62974 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 64444 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 75639 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 53960 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 47872 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 49451 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 43977 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 80482 ['Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 54562 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 53583 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 93117 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 90036 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 82718 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 8872 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 78023 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 15340 ['ZRI_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 48748 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 28905 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 54153 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 92225 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 75771 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 35748 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 16226 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 28638 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 77017 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 38251 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 47660 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 95982 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 76201 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 1104 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 67473 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 78648 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 28133 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 13865 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 71362 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 32764 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 62561 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 48450 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 61554 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 67547 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 38329 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 78415 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 77075 ['PriceToRentRatio_AllHomes']
# DROPPED: ZIP: 16130 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 18517 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 61342 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 38357 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 25535 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 56441 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 5763 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 48659 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 78643 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 89060 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 65453 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 4210 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 16865 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 77360 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 45710 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 61943 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 47165 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 18655 ['ZRI_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 70776 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 49645 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 37857 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 79329 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 37110 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 8733 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 2111 ['Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 56347 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 31523 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 75691 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 53183 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 30241 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 55951 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 77080 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 46115 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 8226 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 25570 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 53086 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 58045 ['PriceToRentRatio_AllHomes', 'ZRI_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 49633 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 58401 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 82834 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 28328 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 40051 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 55454 ['Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 61250 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 81137 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 3458 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 54208 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 43138 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 77979 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 49770 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 78218 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 47164 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 48624 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 75028 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 48763 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 52726 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 49878 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 61356 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 58301 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 76001 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 53923 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 15687 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 21218 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 43713 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 29178 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 67439 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 10027 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 29437 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 98855 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 79928 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 75126 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 2812 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 75006 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 78211 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 74343 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 78657 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 38341 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 84042 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 49078 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 52175 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 53034 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 97741 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 54471 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 46580 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 44429 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 50171 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 77371 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 11763 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 55954 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 76105 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 61813 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 37321 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 28617 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 3057 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 62320 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 76010 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 63549 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 2114 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 25213 ['ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 3284 ['PriceToRentRatio_AllHomes']
#
# DROPPED: ZIP: 52748 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 45243 ['ZRI_AllHomes', 'ZriPerSqft_AllHomes', 'Zri_SingleFamilyResidenceRental']
#
# DROPPED: ZIP: 54568 ['PriceToRentRatio_AllHomes', 'ZriPerSqft_AllHomes']
#
# DROPPED: ZIP: 21530 ['PriceToRentRatio_AllHomes']

# %%
zillow_zip_agg.set_index(['State', 'City', 'ZIP', 'Date'], inplace=True)
zillow_zip_agg.sort_index(inplace=True)
zillow_zip_agg.head()
# Out:
#                             AVG_PriceToRentRatio_AllHomes  AVG_ZRI_AllHomes  \
# State City      ZIP   Date
# AK    Anchorage 99501 2011                      11.971667       1716.250000
#                       2012                      11.373333       1744.333333
#                       2013                      10.759167       1831.166667
#                       2014                      11.285833       1814.000000
#                       2015                      11.081667       1823.666667
#
#                             AVG_ZriPerSqft_AllHomes  \
# State City      ZIP   Date
# AK    Anchorage 99501 2011                 1.431167
#                       2012                 1.505167
#                       2013                 1.562833
#                       2014                 1.571667
#                       2015                 1.640500
#
#                             AVG_Zri_SingleFamilyResidenceRental
# State City      ZIP   Date
# AK    Anchorage 99501 2011                          1846.916667
#                       2012                          1871.833333
#                       2013                          1951.833333
#                       2014                          1901.333333
#                       2015                          1955.916667

# %%
zillow_zip_agg.groupby(['State', 'City', 'ZIP', 'Date']).ngroups
# Out:
# 90702
